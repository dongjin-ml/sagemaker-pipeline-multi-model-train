# %%
import boto3
from sagemaker.session import Session
from sagemaker import get_execution_role

role = get_execution_role()

sagemaker_session = Session()

bucket = sagemaker_session.default_bucket()
prefix = "model-card-sample-notebook"

region = sagemaker_session.boto_region_name
s3 = boto3.client("s3", region_name=region)

# %%
import io
import os
import numpy as np
from six.moves.urllib.parse import urlparse
from pprint import pprint
import boto3
import sagemaker
from sagemaker.image_uris import retrieve
import sagemaker.amazon.common as smac
from sagemaker.model_card import (
    ModelCard,
    ModelOverview,
    ObjectiveFunction,
    Function,
    TrainingDetails,
    IntendedUses,
    EvaluationJob,
    AdditionalInformation,
    Metric,
    MetricGroup,
    ModelCardStatusEnum,
    ObjectiveFunctionEnum,
    FacetEnum,
    RiskRatingEnum,
    MetricTypeEnum,
    EvaluationMetricTypeEnum,
)

# %%
# synthetic data
raw_data = (
    (0.5, 0),
    (0.75, 0),
    (1.0, 0),
    (1.25, 0),
    (1.50, 0),
    (1.75, 0),
    (2.0, 0),
    (2.25, 1),
    (2.5, 0),
    (2.75, 1),
    (3.0, 0),
    (3.25, 1),
    (3.5, 0),
    (4.0, 1),
    (4.25, 1),
    (4.5, 1),
    (4.75, 1),
    (5.0, 1),
    (5.5, 1),
)
training_data = np.array(raw_data).astype("float32")
labels = training_data[:, 1]

# upload data to S3 bucket
buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, training_data, labels)
buf.seek(0)
boto3.resource("s3").Bucket(bucket).Object(os.path.join(prefix, "train")).upload_fileobj(buf)

# %%
s3_train_data = f"s3://{bucket}/{prefix}/train"
output_location = f"s3://{bucket}/{prefix}/output"
container = retrieve("linear-learner", sagemaker_session.boto_session.region_name)
estimator = sagemaker.estimator.Estimator(
    container,
    role=role,
    instance_count=1,
    instance_type="ml.m4.xlarge",
    output_path=output_location,
    sagemaker_session=sagemaker_session,
)
estimator.set_hyperparameters(feature_dim=2, mini_batch_size=10, predictor_type="binary_classifier")
estimator.fit({"train": s3_train_data})
print(f"Training job name: {estimator.latest_training_job.name}")
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: 1.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: linear-learner-2023-01-20-02-39-16-216
# 2023-01-20 02:39:16 Starting - Starting the training job...
# 2023-01-20 02:39:42 Starting - Preparing the instances for training......
# 2023-01-20 02:40:36 Downloading - Downloading input data...
# 2023-01-20 02:41:07 Training - Downloading the training image......
# 2023-01-20 02:42:12 Training - Training image download completed. Training in progress....
# 2023-01-20 02:42:48 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [01/20/2023 02:42:37 INFO 140290109187904] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [01/20/2023 02:42:37 INFO 140290109187904] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '2', 'mini_batch_size': '10', 'predictor_type': 'binary_classifier'}
# [01/20/2023 02:42:37 INFO 140290109187904] Final configuration: {'mini_batch_size': '10', 'epochs': '15', 'feature_dim': '2', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [01/20/2023 02:42:40 WARNING 140290109187904] Loggers have already been setup.
# [01/20/2023 02:42:40 INFO 140290109187904] Final configuration: {'mini_batch_size': '10', 'epochs': '15', 'feature_dim': '2', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [01/20/2023 02:42:40 WARNING 140290109187904] Loggers have already been setup.
# Process 7 is a worker.
# [01/20/2023 02:42:40 INFO 140290109187904] Using default worker.
# [01/20/2023 02:42:40 INFO 140290109187904] Checkpoint loading and saving are disabled.
# [2023-01-20 02:42:40.697] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 16, "num_examples": 1, "num_bytes": 520}
# [01/20/2023 02:42:40 INFO 140290109187904] Create Store: local
# [2023-01-20 02:42:40.712] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 13, "num_examples": 2, "num_bytes": 988}
# [01/20/2023 02:42:40 INFO 140290109187904] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f974cc2e350>
# [01/20/2023 02:42:40 INFO 140290109187904] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [0.7180703 0.4      ]
# <NDArray 2 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [1.625 0.2  ]
# <NDArray 2 @cpu(0)>}
# [01/20/2023 02:42:40 INFO 140290109187904] nvidia-smi: took 0.032 seconds to run.
# [01/20/2023 02:42:40 INFO 140290109187904] nvidia-smi identified 0 GPUs.
# [01/20/2023 02:42:40 INFO 140290109187904] Number of GPUs being used: 0
# #metrics {"StartTime": 1674182560.8289294, "EndTime": 1674182560.8289661, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 29.0, "count": 1, "min": 29, "max": 29}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2023-01-20 02:42:40.884] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 55, "num_examples": 2, "num_bytes": 988}
# #metrics {"StartTime": 1674182560.8848953, "EndTime": 1674182560.884998, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6863228797912597, "count": 1, "min": 0.6863228797912597, "max": 0.6863228797912597}}}
# #metrics {"StartTime": 1674182560.8851094, "EndTime": 1674182560.8851357, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6932838916778564, "count": 1, "min": 0.6932838916778564, "max": 0.6932838916778564}}}
# #metrics {"StartTime": 1674182560.8851995, "EndTime": 1674182560.8852193, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6933170318603515, "count": 1, "min": 0.6933170318603515, "max": 0.6933170318603515}}}
# #metrics {"StartTime": 1674182560.8852835, "EndTime": 1674182560.8853035, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.683878755569458, "count": 1, "min": 0.683878755569458, "max": 0.683878755569458}}}
# #metrics {"StartTime": 1674182560.8853748, "EndTime": 1674182560.8853939, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7034980297088623, "count": 1, "min": 0.7034980297088623, "max": 0.7034980297088623}}}
# #metrics {"StartTime": 1674182560.8854659, "EndTime": 1674182560.885484, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6644838333129883, "count": 1, "min": 0.6644838333129883, "max": 0.6644838333129883}}}
# #metrics {"StartTime": 1674182560.885552, "EndTime": 1674182560.8855672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7148267269134522, "count": 1, "min": 0.7148267269134522, "max": 0.7148267269134522}}}
# #metrics {"StartTime": 1674182560.8856277, "EndTime": 1674182560.885647, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6975635051727295, "count": 1, "min": 0.6975635051727295, "max": 0.6975635051727295}}}
# #metrics {"StartTime": 1674182560.8857167, "EndTime": 1674182560.8857374, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7193428039550781, "count": 1, "min": 0.7193428039550781, "max": 0.7193428039550781}}}
# #metrics {"StartTime": 1674182560.8858035, "EndTime": 1674182560.885818, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6710386276245117, "count": 1, "min": 0.6710386276245117, "max": 0.6710386276245117}}}
# #metrics {"StartTime": 1674182560.8858893, "EndTime": 1674182560.8859038, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6671507835388184, "count": 1, "min": 0.6671507835388184, "max": 0.6671507835388184}}}
# #metrics {"StartTime": 1674182560.88597, "EndTime": 1674182560.8859901, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6700453281402587, "count": 1, "min": 0.6700453281402587, "max": 0.6700453281402587}}}
# #metrics {"StartTime": 1674182560.886056, "EndTime": 1674182560.8860724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6725164890289307, "count": 1, "min": 0.6725164890289307, "max": 0.6725164890289307}}}
# #metrics {"StartTime": 1674182560.8861394, "EndTime": 1674182560.886156, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6888559818267822, "count": 1, "min": 0.6888559818267822, "max": 0.6888559818267822}}}
# #metrics {"StartTime": 1674182560.8862238, "EndTime": 1674182560.8862412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.694678544998169, "count": 1, "min": 0.694678544998169, "max": 0.694678544998169}}}
# #metrics {"StartTime": 1674182560.8862998, "EndTime": 1674182560.8863235, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7067623615264893, "count": 1, "min": 0.7067623615264893, "max": 0.7067623615264893}}}
# #metrics {"StartTime": 1674182560.8863926, "EndTime": 1674182560.8864057, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7049431800842285, "count": 1, "min": 0.7049431800842285, "max": 0.7049431800842285}}}
# #metrics {"StartTime": 1674182560.8864763, "EndTime": 1674182560.8864946, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6903971672058106, "count": 1, "min": 0.6903971672058106, "max": 0.6903971672058106}}}
# #metrics {"StartTime": 1674182560.8865595, "EndTime": 1674182560.8865762, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6984170913696289, "count": 1, "min": 0.6984170913696289, "max": 0.6984170913696289}}}
# #metrics {"StartTime": 1674182560.8866448, "EndTime": 1674182560.8866599, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6664309501647949, "count": 1, "min": 0.6664309501647949, "max": 0.6664309501647949}}}
# #metrics {"StartTime": 1674182560.886726, "EndTime": 1674182560.8867457, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6968473434448242, "count": 1, "min": 0.6968473434448242, "max": 0.6968473434448242}}}
# #metrics {"StartTime": 1674182560.8868108, "EndTime": 1674182560.8868294, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6609521865844726, "count": 1, "min": 0.6609521865844726, "max": 0.6609521865844726}}}
# #metrics {"StartTime": 1674182560.8868966, "EndTime": 1674182560.8869145, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7176124572753906, "count": 1, "min": 0.7176124572753906, "max": 0.7176124572753906}}}
# #metrics {"StartTime": 1674182560.8869855, "EndTime": 1674182560.8870046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6992251396179199, "count": 1, "min": 0.6992251396179199, "max": 0.6992251396179199}}}
# #metrics {"StartTime": 1674182560.8871005, "EndTime": 1674182560.8871202, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7176902294158936, "count": 1, "min": 0.7176902294158936, "max": 0.7176902294158936}}}
# #metrics {"StartTime": 1674182560.8871884, "EndTime": 1674182560.887206, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6574334144592285, "count": 1, "min": 0.6574334144592285, "max": 0.6574334144592285}}}
# #metrics {"StartTime": 1674182560.887275, "EndTime": 1674182560.887291, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7040048122406006, "count": 1, "min": 0.7040048122406006, "max": 0.7040048122406006}}}
# #metrics {"StartTime": 1674182560.8873577, "EndTime": 1674182560.887374, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6608765602111817, "count": 1, "min": 0.6608765602111817, "max": 0.6608765602111817}}}
# #metrics {"StartTime": 1674182560.8874419, "EndTime": 1674182560.8874626, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6788201332092285, "count": 1, "min": 0.6788201332092285, "max": 0.6788201332092285}}}
# #metrics {"StartTime": 1674182560.8875203, "EndTime": 1674182560.8875346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6667984962463379, "count": 1, "min": 0.6667984962463379, "max": 0.6667984962463379}}}
# #metrics {"StartTime": 1674182560.8875866, "EndTime": 1674182560.8876078, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.673979377746582, "count": 1, "min": 0.673979377746582, "max": 0.673979377746582}}}
# #metrics {"StartTime": 1674182560.8876724, "EndTime": 1674182560.8876877, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6940407276153564, "count": 1, "min": 0.6940407276153564, "max": 0.6940407276153564}}}
# [01/20/2023 02:42:40 INFO 140290109187904] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.6863228797912597
# [01/20/2023 02:42:40 INFO 140290109187904] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.6574334144592285
# [01/20/2023 02:42:40 INFO 140290109187904] Epoch 0: Loss improved. Updating best model
# [01/20/2023 02:42:40 INFO 140290109187904] Saving model for epoch: 0
# [01/20/2023 02:42:40 INFO 140290109187904] Saved checkpoint to "/tmp/tmp25d653c8/mx-mod-0000.params"
# [01/20/2023 02:42:40 INFO 140290109187904] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1674182560.8292634, "EndTime": 1674182560.8986301, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 48.0, "count": 1, "min": 48, "max": 48}, "Total Batches Seen": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Records Seen Between Resets": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
# [01/20/2023 02:42:40 INFO 140290109187904] #throughput_metric: host=algo-1, train throughput=273.36078428682174 records/second
# [2023-01-20 02:42:40.932] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 33, "num_examples": 2, "num_bytes": 988}
# #metrics {"StartTime": 1674182560.9329154, "EndTime": 1674182560.9329965, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6684666633605957, "count": 1, "min": 0.6684666633605957, "max": 0.6684666633605957}}}
# #metrics {"StartTime": 1674182560.9330666, "EndTime": 1674182560.9330878, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6753902435302734, "count": 1, "min": 0.6753902435302734, "max": 0.6753902435302734}}}
# #metrics {"StartTime": 1674182560.933157, "EndTime": 1674182560.9331794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6754158496856689, "count": 1, "min": 0.6754158496856689, "max": 0.6754158496856689}}}
# #metrics {"StartTime": 1674182560.9332352, "EndTime": 1674182560.9332561, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.666045093536377, "count": 1, "min": 0.666045093536377, "max": 0.666045093536377}}}
# #metrics {"StartTime": 1674182560.9333086, "EndTime": 1674182560.9333239, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4609829902648926, "count": 1, "min": 0.4609829902648926, "max": 0.4609829902648926}}}
# #metrics {"StartTime": 1674182560.9333782, "EndTime": 1674182560.933398, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4265033721923828, "count": 1, "min": 0.4265033721923828, "max": 0.4265033721923828}}}
# #metrics {"StartTime": 1674182560.933446, "EndTime": 1674182560.9334626, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.47202496528625487, "count": 1, "min": 0.47202496528625487, "max": 0.47202496528625487}}}
# #metrics {"StartTime": 1674182560.9335256, "EndTime": 1674182560.9335434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4560309886932373, "count": 1, "min": 0.4560309886932373, "max": 0.4560309886932373}}}
# #metrics {"StartTime": 1674182560.9335895, "EndTime": 1674182560.9336047, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.701291561126709, "count": 1, "min": 0.701291561126709, "max": 0.701291561126709}}}
# #metrics {"StartTime": 1674182560.933666, "EndTime": 1674182560.9336908, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6532862663269043, "count": 1, "min": 0.6532862663269043, "max": 0.6532862663269043}}}
# #metrics {"StartTime": 1674182560.933741, "EndTime": 1674182560.9337575, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6494121074676513, "count": 1, "min": 0.6494121074676513, "max": 0.6494121074676513}}}
# #metrics {"StartTime": 1674182560.9338124, "EndTime": 1674182560.9338303, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.652278995513916, "count": 1, "min": 0.652278995513916, "max": 0.652278995513916}}}
# #metrics {"StartTime": 1674182560.9338834, "EndTime": 1674182560.9339018, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.43326740264892577, "count": 1, "min": 0.43326740264892577, "max": 0.43326740264892577}}}
# #metrics {"StartTime": 1674182560.9339507, "EndTime": 1674182560.9339664, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4480618476867676, "count": 1, "min": 0.4480618476867676, "max": 0.4480618476867676}}}
# #metrics {"StartTime": 1674182560.9340212, "EndTime": 1674182560.934036, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.45377292633056643, "count": 1, "min": 0.45377292633056643, "max": 0.45377292633056643}}}
# #metrics {"StartTime": 1674182560.9340937, "EndTime": 1674182560.9341118, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4644986629486084, "count": 1, "min": 0.4644986629486084, "max": 0.4644986629486084}}}
# #metrics {"StartTime": 1674182560.934163, "EndTime": 1674182560.9341779, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6870324611663818, "count": 1, "min": 0.6870324611663818, "max": 0.6870324611663818}}}
# #metrics {"StartTime": 1674182560.9342318, "EndTime": 1674182560.9342437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6725673675537109, "count": 1, "min": 0.6725673675537109, "max": 0.6725673675537109}}}
# #metrics {"StartTime": 1674182560.9343064, "EndTime": 1674182560.934326, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6804818630218505, "count": 1, "min": 0.6804818630218505, "max": 0.6804818630218505}}}
# #metrics {"StartTime": 1674182560.9343743, "EndTime": 1674182560.9343894, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.648704719543457, "count": 1, "min": 0.648704719543457, "max": 0.648704719543457}}}
# #metrics {"StartTime": 1674182560.9344482, "EndTime": 1674182560.9344678, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.45563392639160155, "count": 1, "min": 0.45563392639160155, "max": 0.45563392639160155}}}
# #metrics {"StartTime": 1674182560.9345143, "EndTime": 1674182560.9345255, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4232292175292969, "count": 1, "min": 0.4232292175292969, "max": 0.4232292175292969}}}
# #metrics {"StartTime": 1674182560.934581, "EndTime": 1674182560.9345994, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4737660884857178, "count": 1, "min": 0.4737660884857178, "max": 0.4737660884857178}}}
# #metrics {"StartTime": 1674182560.9346573, "EndTime": 1674182560.934674, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4569636344909668, "count": 1, "min": 0.4569636344909668, "max": 0.4569636344909668}}}
# #metrics {"StartTime": 1674182560.9347343, "EndTime": 1674182560.9347482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.69962158203125, "count": 1, "min": 0.69962158203125, "max": 0.69962158203125}}}
# #metrics {"StartTime": 1674182560.934803, "EndTime": 1674182560.9348176, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6457526683807373, "count": 1, "min": 0.6457526683807373, "max": 0.6457526683807373}}}
# #metrics {"StartTime": 1674182560.9348752, "EndTime": 1674182560.9348886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6884944438934326, "count": 1, "min": 0.6884944438934326, "max": 0.6884944438934326}}}
# #metrics {"StartTime": 1674182560.9349418, "EndTime": 1674182560.9349532, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6492094993591309, "count": 1, "min": 0.6492094993591309, "max": 0.6492094993591309}}}
# #metrics {"StartTime": 1674182560.9350162, "EndTime": 1674182560.9350345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.48342695236206057, "count": 1, "min": 0.48342695236206057, "max": 0.48342695236206057}}}
# #metrics {"StartTime": 1674182560.9351172, "EndTime": 1674182560.935136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5516231536865235, "count": 1, "min": 0.5516231536865235, "max": 0.5516231536865235}}}
# #metrics {"StartTime": 1674182560.935198, "EndTime": 1674182560.9352143, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5594757556915283, "count": 1, "min": 0.5594757556915283, "max": 0.5594757556915283}}}
# #metrics {"StartTime": 1674182560.9352624, "EndTime": 1674182560.9352791, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5298561096191406, "count": 1, "min": 0.5298561096191406, "max": 0.5298561096191406}}}
# [01/20/2023 02:42:40 INFO 140290109187904] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.6684666633605957
# [01/20/2023 02:42:40 INFO 140290109187904] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.4232292175292969
# [01/20/2023 02:42:40 INFO 140290109187904] Epoch 1: Loss improved. Updating best model
# [01/20/2023 02:42:40 INFO 140290109187904] Saving model for epoch: 1
# [01/20/2023 02:42:40 INFO 140290109187904] Saved checkpoint to "/tmp/tmpe165w044/mx-mod-0000.params"
# [01/20/2023 02:42:40 INFO 140290109187904] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1674182560.8989453, "EndTime": 1674182560.9442503, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 67.0, "count": 1, "min": 67, "max": 67}, "Total Batches Seen": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Max Records Seen Between Resets": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
# [01/20/2023 02:42:40 INFO 140290109187904] #throughput_metric: host=algo-1, train throughput=417.84478898495706 records/second
# [2023-01-20 02:42:40.982] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 37, "num_examples": 2, "num_bytes": 988}
# #metrics {"StartTime": 1674182560.9825652, "EndTime": 1674182560.9826517, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6512737274169922, "count": 1, "min": 0.6512737274169922, "max": 0.6512737274169922}}}
# #metrics {"StartTime": 1674182560.982729, "EndTime": 1674182560.9827638, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6581601142883301, "count": 1, "min": 0.6581601142883301, "max": 0.6581601142883301}}}
# #metrics {"StartTime": 1674182560.9828324, "EndTime": 1674182560.982852, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6581781387329102, "count": 1, "min": 0.6581781387329102, "max": 0.6581781387329102}}}
# #metrics {"StartTime": 1674182560.9829113, "EndTime": 1674182560.9829278, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6488744735717773, "count": 1, "min": 0.6488744735717773, "max": 0.6488744735717773}}}
# #metrics {"StartTime": 1674182560.982997, "EndTime": 1674182560.9830127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.40248608589172363, "count": 1, "min": 0.40248608589172363, "max": 0.40248608589172363}}}
# #metrics {"StartTime": 1674182560.9830995, "EndTime": 1674182560.983118, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.36945147514343263, "count": 1, "min": 0.36945147514343263, "max": 0.36945147514343263}}}
# #metrics {"StartTime": 1674182560.983176, "EndTime": 1674182560.9831896, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.41328773498535154, "count": 1, "min": 0.41328773498535154, "max": 0.41328773498535154}}}
# #metrics {"StartTime": 1674182560.983257, "EndTime": 1674182560.983274, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.39787921905517576, "count": 1, "min": 0.39787921905517576, "max": 0.39787921905517576}}}
# #metrics {"StartTime": 1674182560.9833386, "EndTime": 1674182560.9833534, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6839038848876953, "count": 1, "min": 0.6839038848876953, "max": 0.6839038848876953}}}
# #metrics {"StartTime": 1674182560.9834104, "EndTime": 1674182560.9834266, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6361963272094726, "count": 1, "min": 0.6361963272094726, "max": 0.6361963272094726}}}
# #metrics {"StartTime": 1674182560.983478, "EndTime": 1674182560.983495, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.632335901260376, "count": 1, "min": 0.632335901260376, "max": 0.632335901260376}}}
# #metrics {"StartTime": 1674182560.9835405, "EndTime": 1674182560.9835575, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6351752281188965, "count": 1, "min": 0.6351752281188965, "max": 0.6351752281188965}}}
# #metrics {"StartTime": 1674182560.9836078, "EndTime": 1674182560.9836245, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.37595882415771487, "count": 1, "min": 0.37595882415771487, "max": 0.37595882415771487}}}
# #metrics {"StartTime": 1674182560.983673, "EndTime": 1674182560.9836893, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3902148246765137, "count": 1, "min": 0.3902148246765137, "max": 0.3902148246765137}}}
# #metrics {"StartTime": 1674182560.98374, "EndTime": 1674182560.9837558, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3958014965057373, "count": 1, "min": 0.3958014965057373, "max": 0.3958014965057373}}}
# #metrics {"StartTime": 1674182560.9838018, "EndTime": 1674182560.9838178, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.40604095458984374, "count": 1, "min": 0.40604095458984374, "max": 0.40604095458984374}}}
# #metrics {"StartTime": 1674182560.9838684, "EndTime": 1674182560.9838848, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6697864532470703, "count": 1, "min": 0.6697864532470703, "max": 0.6697864532470703}}}
# #metrics {"StartTime": 1674182560.983931, "EndTime": 1674182560.983947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6554020881652832, "count": 1, "min": 0.6554020881652832, "max": 0.6554020881652832}}}
# #metrics {"StartTime": 1674182560.983998, "EndTime": 1674182560.9840136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6632116317749024, "count": 1, "min": 0.6632116317749024, "max": 0.6632116317749024}}}
# #metrics {"StartTime": 1674182560.9840612, "EndTime": 1674182560.984075, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6316425800323486, "count": 1, "min": 0.6316425800323486, "max": 0.6316425800323486}}}
# #metrics {"StartTime": 1674182560.9841256, "EndTime": 1674182560.9841404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.40009326934814454, "count": 1, "min": 0.40009326934814454, "max": 0.40009326934814454}}}
# #metrics {"StartTime": 1674182560.9841886, "EndTime": 1674182560.9842048, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.37112486362457275, "count": 1, "min": 0.37112486362457275, "max": 0.37112486362457275}}}
# #metrics {"StartTime": 1674182560.9842525, "EndTime": 1674182560.9842699, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.416380786895752, "count": 1, "min": 0.416380786895752, "max": 0.416380786895752}}}
# #metrics {"StartTime": 1674182560.9843175, "EndTime": 1674182560.9843335, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4005228042602539, "count": 1, "min": 0.4005228042602539, "max": 0.4005228042602539}}}
# #metrics {"StartTime": 1674182560.984394, "EndTime": 1674182560.9844122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6822481155395508, "count": 1, "min": 0.6822481155395508, "max": 0.6822481155395508}}}
# #metrics {"StartTime": 1674182560.9844599, "EndTime": 1674182560.9844751, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6347217559814453, "count": 1, "min": 0.6347217559814453, "max": 0.6347217559814453}}}
# #metrics {"StartTime": 1674182560.9845233, "EndTime": 1674182560.9845412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6736313343048096, "count": 1, "min": 0.6736313343048096, "max": 0.6736313343048096}}}
# #metrics {"StartTime": 1674182560.9845886, "EndTime": 1674182560.9846036, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6381911277770996, "count": 1, "min": 0.6381911277770996, "max": 0.6381911277770996}}}
# #metrics {"StartTime": 1674182560.9846513, "EndTime": 1674182560.9846683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5169202804565429, "count": 1, "min": 0.5169202804565429, "max": 0.5169202804565429}}}
# #metrics {"StartTime": 1674182560.9847152, "EndTime": 1674182560.9847293, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5341668605804444, "count": 1, "min": 0.5341668605804444, "max": 0.5341668605804444}}}
# #metrics {"StartTime": 1674182560.9847794, "EndTime": 1674182560.9847977, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5298550605773926, "count": 1, "min": 0.5298550605773926, "max": 0.5298550605773926}}}
# #metrics {"StartTime": 1674182560.9848468, "EndTime": 1674182560.984859, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5102839469909668, "count": 1, "min": 0.5102839469909668, "max": 0.5102839469909668}}}
# [01/20/2023 02:42:40 INFO 140290109187904] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.6512737274169922
# [01/20/2023 02:42:40 INFO 140290109187904] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.36945147514343263
# [01/20/2023 02:42:40 INFO 140290109187904] Epoch 2: Loss improved. Updating best model
# [01/20/2023 02:42:40 INFO 140290109187904] Saving model for epoch: 2
# [01/20/2023 02:42:40 INFO 140290109187904] Saved checkpoint to "/tmp/tmp204hxxh5/mx-mod-0000.params"
# [01/20/2023 02:42:40 INFO 140290109187904] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1674182560.9445903, "EndTime": 1674182560.9946706, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 86.0, "count": 1, "min": 86, "max": 86}, "Total Batches Seen": {"sum": 9.0, "count": 1, "min": 9, "max": 9}, "Max Records Seen Between Resets": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
# [01/20/2023 02:42:40 INFO 140290109187904] #throughput_metric: host=algo-1, train throughput=378.1772348927043 records/second
# [2023-01-20 02:42:41.035] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 39, "num_examples": 2, "num_bytes": 988}
# #metrics {"StartTime": 1674182561.0352023, "EndTime": 1674182561.0352962, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6347530841827392, "count": 1, "min": 0.6347530841827392, "max": 0.6347530841827392}}}
# #metrics {"StartTime": 1674182561.0353973, "EndTime": 1674182561.0354207, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.641602611541748, "count": 1, "min": 0.641602611541748, "max": 0.641602611541748}}}
# #metrics {"StartTime": 1674182561.0354862, "EndTime": 1674182561.0355067, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6416131973266601, "count": 1, "min": 0.6416131973266601, "max": 0.6416131973266601}}}
# #metrics {"StartTime": 1674182561.035577, "EndTime": 1674182561.0356002, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6323761940002441, "count": 1, "min": 0.6323761940002441, "max": 0.6323761940002441}}}
# ...
# #metrics {"StartTime": 1674182561.5735462, "EndTime": 1674182561.5735629, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.49510650634765624, "count": 1, "min": 0.49510650634765624, "max": 0.49510650634765624}}}
# #metrics {"StartTime": 1674182561.5736284, "EndTime": 1674182561.5736425, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.10047831535339355, "count": 1, "min": 0.10047831535339355, "max": 0.10047831535339355}}}
# #metrics {"StartTime": 1674182561.5737023, "EndTime": 1674182561.5737147, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.09488514661788941, "count": 1, "min": 0.09488514661788941, "max": 0.09488514661788941}}}
# #metrics {"StartTime": 1674182561.573778, "EndTime": 1674182561.5737944, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.10457742214202881, "count": 1, "min": 0.10457742214202881, "max": 0.10457742214202881}}}
# #metrics {"StartTime": 1674182561.573853, "EndTime": 1674182561.5738704, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.09996130466461181, "count": 1, "min": 0.09996130466461181, "max": 0.09996130466461181}}}
# #metrics {"StartTime": 1674182561.5739367, "EndTime": 1674182561.5739493, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.528169059753418, "count": 1, "min": 0.528169059753418, "max": 0.528169059753418}}}
# #metrics {"StartTime": 1674182561.5740025, "EndTime": 1674182561.5740235, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4832622528076172, "count": 1, "min": 0.4832622528076172, "max": 0.4832622528076172}}}
# #metrics {"StartTime": 1674182561.5740705, "EndTime": 1674182561.5740871, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.47991137504577636, "count": 1, "min": 0.47991137504577636, "max": 0.47991137504577636}}}
# #metrics {"StartTime": 1674182561.5741513, "EndTime": 1674182561.5741668, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.48211145401000977, "count": 1, "min": 0.48211145401000977, "max": 0.48211145401000977}}}
# #metrics {"StartTime": 1674182561.5742211, "EndTime": 1674182561.57424, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.09599298238754272, "count": 1, "min": 0.09599298238754272, "max": 0.09599298238754272}}}
# #metrics {"StartTime": 1674182561.574298, "EndTime": 1674182561.5743144, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.09871869087219239, "count": 1, "min": 0.09871869087219239, "max": 0.09871869087219239}}}
# #metrics {"StartTime": 1674182561.57437, "EndTime": 1674182561.5743878, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.10122885704040527, "count": 1, "min": 0.10122885704040527, "max": 0.10122885704040527}}}
# #metrics {"StartTime": 1674182561.5744429, "EndTime": 1674182561.5744607, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.10266188383102418, "count": 1, "min": 0.10266188383102418, "max": 0.10266188383102418}}}
# #metrics {"StartTime": 1674182561.5745184, "EndTime": 1674182561.574537, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5161350727081299, "count": 1, "min": 0.5161350727081299, "max": 0.5161350727081299}}}
# #metrics {"StartTime": 1674182561.5745926, "EndTime": 1674182561.5746202, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5023158073425293, "count": 1, "min": 0.5023158073425293, "max": 0.5023158073425293}}}
# #metrics {"StartTime": 1674182561.574682, "EndTime": 1674182561.5746975, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5092257976531982, "count": 1, "min": 0.5092257976531982, "max": 0.5092257976531982}}}
# #metrics {"StartTime": 1674182561.5747461, "EndTime": 1674182561.5747662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.47964935302734374, "count": 1, "min": 0.47964935302734374, "max": 0.47964935302734374}}}
# #metrics {"StartTime": 1674182561.5748215, "EndTime": 1674182561.5748343, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.37715444564819334, "count": 1, "min": 0.37715444564819334, "max": 0.37715444564819334}}}
# #metrics {"StartTime": 1674182561.5749004, "EndTime": 1674182561.5749214, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.38382301330566404, "count": 1, "min": 0.38382301330566404, "max": 0.38382301330566404}}}
# #metrics {"StartTime": 1674182561.5749762, "EndTime": 1674182561.5749938, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.37232494354248047, "count": 1, "min": 0.37232494354248047, "max": 0.37232494354248047}}}
# #metrics {"StartTime": 1674182561.5750535, "EndTime": 1674182561.5750947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3895202875137329, "count": 1, "min": 0.3895202875137329, "max": 0.3895202875137329}}}
# #metrics {"StartTime": 1674182561.5751605, "EndTime": 1674182561.5751753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5442564487457275, "count": 1, "min": 0.5442564487457275, "max": 0.5442564487457275}}}
# #metrics {"StartTime": 1674182561.57524, "EndTime": 1674182561.575263, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5478240013122558, "count": 1, "min": 0.5478240013122558, "max": 0.5478240013122558}}}
# #metrics {"StartTime": 1674182561.575331, "EndTime": 1674182561.5753448, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5455855369567871, "count": 1, "min": 0.5455855369567871, "max": 0.5455855369567871}}}
# #metrics {"StartTime": 1674182561.5754173, "EndTime": 1674182561.575434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5503373622894288, "count": 1, "min": 0.5503373622894288, "max": 0.5503373622894288}}}
# #metrics {"StartTime": 1674182561.5755007, "EndTime": 1674182561.5755193, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5150843620300293, "count": 1, "min": 0.5150843620300293, "max": 0.5150843620300293}}}
# #metrics {"StartTime": 1674182561.5755816, "EndTime": 1674182561.575598, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.49188899993896484, "count": 1, "min": 0.49188899993896484, "max": 0.49188899993896484}}}
# #metrics {"StartTime": 1674182561.5756667, "EndTime": 1674182561.575686, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.48805923461914064, "count": 1, "min": 0.48805923461914064, "max": 0.48805923461914064}}}
# #metrics {"StartTime": 1674182561.5757508, "EndTime": 1674182561.5757663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5002636909484863, "count": 1, "min": 0.5002636909484863, "max": 0.5002636909484863}}}
# [01/20/2023 02:42:41 INFO 140290109187904] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.49764213562011717
# [01/20/2023 02:42:41 INFO 140290109187904] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.09488514661788941
# [01/20/2023 02:42:41 INFO 140290109187904] Epoch 14: Loss improved. Updating best model
# [01/20/2023 02:42:41 INFO 140290109187904] Saving model for epoch: 14
# [01/20/2023 02:42:41 INFO 140290109187904] Saved checkpoint to "/tmp/tmpvxkgj8ur/mx-mod-0000.params"
# [01/20/2023 02:42:41 INFO 140290109187904] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1674182561.529798, "EndTime": 1674182561.5845397, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 314.0, "count": 1, "min": 314, "max": 314}, "Total Batches Seen": {"sum": 33.0, "count": 1, "min": 33, "max": 33}, "Max Records Seen Between Resets": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
# [01/20/2023 02:42:41 INFO 140290109187904] #throughput_metric: host=algo-1, train throughput=346.19999131152525 records/second
# [01/20/2023 02:42:41 WARNING 140290109187904] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/20/2023 02:42:41 WARNING 140290109187904] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2023-01-20 02:42:41.585] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 34, "duration": 0, "num_examples": 1, "num_bytes": 520}
# [2023-01-20 02:42:41.695] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 37, "duration": 107, "num_examples": 2, "num_bytes": 988}
# [2023-01-20 02:42:41.718] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 39, "duration": 8, "num_examples": 2, "num_bytes": 988}
# [01/20/2023 02:42:41 INFO 140290109187904] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.13517043151353536)
# [01/20/2023 02:42:41 INFO 140290109187904] #train_score (algo-1) : ('binary_classification_accuracy', 0.9473684210526315)
# [01/20/2023 02:42:41 INFO 140290109187904] #train_score (algo-1) : ('binary_f_1.000', 0.9473684210526315)
# [01/20/2023 02:42:41 INFO 140290109187904] #train_score (algo-1) : ('precision', 0.9)
# [01/20/2023 02:42:41 INFO 140290109187904] #train_score (algo-1) : ('recall', 1.0)
# [01/20/2023 02:42:41 INFO 140290109187904] #train_score (algo-1) : ('roc_auc_score', 1.0)
# [01/20/2023 02:42:41 INFO 140290109187904] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [01/20/2023 02:42:41 INFO 140290109187904] #train_score (algo-1) : ('binary_log_loss', 0.565831215078832)
# [01/20/2023 02:42:41 INFO 140290109187904] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.13517043151353536
# [01/20/2023 02:42:41 INFO 140290109187904] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.9473684210526315
# [01/20/2023 02:42:41 INFO 140290109187904] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.9473684210526315
# [01/20/2023 02:42:41 INFO 140290109187904] #quality_metric: host=algo-1, train precision <score>=0.9
# [01/20/2023 02:42:41 INFO 140290109187904] #quality_metric: host=algo-1, train recall <score>=1.0
# [01/20/2023 02:42:41 INFO 140290109187904] #quality_metric: host=algo-1, train roc_auc_score <score>=1.0
# [01/20/2023 02:42:41 INFO 140290109187904] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [01/20/2023 02:42:41 INFO 140290109187904] #quality_metric: host=algo-1, train binary_log_loss <score>=0.565831215078832
# [01/20/2023 02:42:41 INFO 140290109187904] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [01/20/2023 02:42:41 INFO 140290109187904] Saved checkpoint to "/tmp/tmpriq0r2kk/mx-mod-0000.params"
# [01/20/2023 02:42:41 INFO 140290109187904] Test data is not provided.
# #metrics {"StartTime": 1674182560.6812694, "EndTime": 1674182561.730607, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 146.68917655944824, "count": 1, "min": 146.68917655944824, "max": 146.68917655944824}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 15.210866928100586, "count": 15, "min": 0.8728504180908203, "max": 1.486063003540039}, "update.time": {"sum": 701.2531757354736, "count": 15, "min": 38.81072998046875, "max": 65.70243835449219}, "finalize.time": {"sum": 139.69135284423828, "count": 1, "min": 139.69135284423828, "max": 139.69135284423828}, "setuptime": {"sum": 2.533435821533203, "count": 1, "min": 2.533435821533203, "max": 2.533435821533203}, "totaltime": {"sum": 1171.689748764038, "count": 1, "min": 1171.689748764038, "max": 1171.689748764038}}}
#
# 2023-01-20 02:42:59 Completed - Training job completed
# Training seconds: 142
# Billable seconds: 142
# Training job name: linear-learner-2023-01-20-02-39-16-216

# %%
model_name = "model-card-test-model"
model = estimator.create_model(name=model_name)
container_def = model.prepare_container_def()
sagemaker_session.create_model(model_name, role, container_def)
print(f"Model name: {model_name}")
# Out:
# INFO:sagemaker:Creating model with name: model-card-test-model
# WARNING:sagemaker:Using already existing model: model-card-test-model
# Model name: model-card-test-model

# %%
model_overview = ModelOverview.from_model_name(
    model_name=model_name,
    sagemaker_session=sagemaker_session,
    model_description="This is an example binary classification model used for a Python SDK demo of Amazon SageMaker Model Cards.",
    problem_type="Binary Classification",
    algorithm_type="Logistic Regression",
    model_creator="DEMO-ModelCard",
    model_owner="DEMO-ModelCard",
)
print(f"Model id: {model_overview.model_id}")
print(f"Model training images: {model_overview.inference_environment.container_image}")
print(f"Model: {model_overview.model_artifact}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_24367/4250563477.py in <cell line: 1>()
# ----> 1 model_overview = ModelOverview.from_model_name(
#       2     model_name=model_name,
#       3     sagemaker_session=sagemaker_session,
#       4     model_description="This is an example binary classification model used for a Python SDK demo of Amazon SageMaker Model Cards.",
#       5     problem_type="Binary Classification",
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/model_card/model_card.py in from_model_name(cls, model_name, sagemaker_session, **kwargs)
#     179         associated_model_cards = search_model_associated_model_cards(model_response["ModelArn"])
#     180         if associated_model_cards:
# --> 181             raise ValueError(
#     182                 f"The model has been associated with {associated_model_cards} model cards."
#     183             )
#
# ValueError: The model has been associated with ['sample-notebook-model-card'] model cards.

# %%
objective_function = ObjectiveFunction(
    function=Function(
        function=ObjectiveFunctionEnum.MINIMIZE,
        facet=FacetEnum.LOSS,
    ),
    notes="This is an example objective function.",
)
training_details = TrainingDetails.from_model_overview(
    model_overview=model_overview,
    sagemaker_session=sagemaker_session,
    objective_function=objective_function,
    training_observations="Add model training observations here.",
)
print(f"Training job id: {training_details.training_job_details.training_arn}")
print(
    f"Training image: {training_details.training_job_details.training_environment.container_image}"
)
print("Training Metrics: ")
pprint(
    [
        {"name": i.name, "value": i.value}
        for i in training_details.training_job_details.training_metrics
    ]
)
# Out:
# Training job id: arn:aws:sagemaker:ap-northeast-2:419974056037:training-job/linear-learner-2023-01-20-02-13-11-792
# Training image: ['835164637446.dkr.ecr.ap-northeast-2.amazonaws.com/linear-learner:1']
# Training Metrics:
# [{'name': 'train:binary_f_beta', 'value': 0.9473684430122375},
#  {'name': 'train:progress', 'value': 100.0},
#  {'name': 'train:objective_loss', 'value': 0.4976421296596527},
#  {'name': 'train:binary_classification_accuracy', 'value': 0.9473684430122375},
#  {'name': 'train:recall', 'value': 1.0},
#  {'name': 'train:precision', 'value': 0.8999999761581421},
#  {'name': 'train:objective_loss:final', 'value': 0.13517042994499207},
#  {'name': 'train:throughput', 'value': 344.0403137207031}]

# %%
manual_metric_group = MetricGroup(
    name="binary classification metrics",
    metric_data=[Metric(name="accuracy", type=MetricTypeEnum.NUMBER, value=0.5)],
)
example_evaluation_job = EvaluationJob(
    name="Example evaluation job",
    evaluation_observation="Evaluation observations.",
    datasets=["s3://path/to/evaluation/data"],
    metric_groups=[manual_metric_group],
)
evaluation_details = [example_evaluation_job]

# %%
intended_uses = IntendedUses(
    purpose_of_model="Test model card.",
    intended_uses="Not used except this test.",
    factors_affecting_model_efficiency="No.",
    risk_rating=RiskRatingEnum.LOW,
    explanations_for_risk_rating="Just an example.",
)
additional_information = AdditionalInformation(
    ethical_considerations="Your model ethical consideration.",
    caveats_and_recommendations="Your model's caveats and recommendations.",
    custom_details={"custom details1": "details value"},
)

# %%
model_card_name = "sample-notebook-model-card"
my_card = ModelCard(
    name=model_card_name,
    status=ModelCardStatusEnum.DRAFT,
    model_overview=model_overview,
    training_details=training_details,
    intended_uses=intended_uses,
    evaluation_details=evaluation_details,
    additional_information=additional_information,
    sagemaker_session=sagemaker_session,
)
my_card.create()
print(f"Model card {my_card.name} is successfully created with id {my_card.arn}")
# Out:
# INFO:sagemaker.model_card.model_card:Creating model card with name: sample-notebook-model-card
# ---------------------------------------------------------------------------
# ConflictException                         Traceback (most recent call last)
# /tmp/ipykernel_24367/2536011371.py in <cell line: 12>()
#      10     sagemaker_session=sagemaker_session,
#      11 )
# ---> 12 my_card.create()
#      13 print(f"Model card {my_card.name} is successfully created with id {my_card.arn}")
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/model_card/model_card.py in create(self)
#     841         logger.info("Creating model card with name: %s", self.name)
#     842         logger.debug("CreateModelCard request: %s", json.dumps(request_args, indent=4))
# --> 843         self.sagemaker_session.sagemaker_client.create_model_card(**request_args)
#     844
#     845         # udpate model card with the latest data from server
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     528                 )
#     529             # The "self" in this scope is referring to the BaseClient.
# --> 530             return self._make_api_call(operation_name, kwargs)
#     531
#     532         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.8/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     958             error_code = parsed_response.get("Error", {}).get("Code")
#     959             error_class = self.exceptions.from_code(error_code)
# --> 960             raise error_class(parsed_response, operation_name)
#     961         else:
#     962             return parsed_response
#
# ConflictException: An error occurred (ConflictException) when calling the CreateModelCard operation: Modelcard arn:aws:sagemaker:ap-northeast-2:419974056037:model-card/sample-notebook-model-card with version 1 already exists

# %%
my_card.model_overview.model_description = "the model is updated."
my_card.update()
# Out:
# INFO:sagemaker.model_card.model_card:Updating model card: sample-notebook-model-card
# INFO:sagemaker.model_card.model_card:Update model card content
# {'content': {'ModelCardArn': 'arn:aws:sagemaker:ap-northeast-2:419974056037:model-card/sample-notebook-model-card',
#   'ResponseMetadata': {'RequestId': '2c76d91c-0737-4a7d-92e7-16af9ef5589f',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amzn-requestid': '2c76d91c-0737-4a7d-92e7-16af9ef5589f',
#     'content-type': 'application/x-amz-json-1.1',
#     'content-length': '102',
#     'date': 'Fri, 20 Jan 2023 02:32:53 GMT'},
#    'RetryAttempts': 0}}}

# %%
model_overview?
# Out:
# Type:           ModelOverview
# String form:    <sagemaker.model_card.model_card.ModelOverview object at 0x7f58236a6d90>
# File:           ~/anaconda3/envs/python3/lib/python3.8/site-packages/sagemaker/model_card/model_card.py
# Docstring:      An overview of the model.
# Init docstring:
# Initialize a Model Overview object.
#
# Args:
#     model_id (str, optional): A SageMaker Model ARN or non-SageMaker Model ID (default: None).
#     model_name (str, optional): A unique name for the model (default: None).
#     model_description (str, optional): A description of the model (default: None).
#     model_version (int or float, optional): The version of the model (default: None).
#     problem_type (str, optional): The type of problem that the model solves. For example, "Binary Classification", "Multiclass Classification", "Linear Regression", "Computer Vision", or "Natural Language Processing" (default: None).
#     algorithm_type (str, optional): The algorithm used to solve the problem type (default: None).
#     model_creator (str, optional): The organization, research group, or authors that created the model (default: None).
#     model_owner (str, optional): The individual or group that maintains the model in your organization (default: None).
#     model_artifact (List[str], optional): A list of model artifact location URIs. The maximum list size is 15. (default: None).
#     inference_environment (Environment, optional): An overview of the model's inference environment (default: None).
